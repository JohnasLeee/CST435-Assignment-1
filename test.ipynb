# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests
from io import StringIO
import utils

data = utils.get_SP500()
# Out:
# Fetching S&P 500 company list from Wikipedia...
# Number of tickers: 503
# ...
# Date range: 2013-01-01 to 2023-12-31
# Total tickers to download: 503
# c:\Users\ASUS\Documents\CST435\CST435 Assignment 1\utils.py:41: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(
# [*********************100%***********************]  8 of 8 completed
# Successfully downloaded data for 8 tickers
# Data shape: (2768, 40)
#
# Data columns (first 10): [('AMD', 'Open'), ('AMD', 'High'), ('AMD', 'Low'), ('AMD', 'Close'), ('AMD', 'Volume'), ('ADBE', 'Open'), ('ADBE', 'High'), ('ADBE', 'Low'), ('ADBE', 'Close'), ('ADBE', 'Volume')]
# Date range: 2013-01-02 00:00:00 to 2023-12-29 00:00:00

# %%
# Add negative rank columns
data = utils.get_negative_rank_returns_only(data)
# Out:
# Computing -rank(returns) for 8 tickers...
# Created DataFrame with 8 -rank(returns) columns
# Date range: 2013-01-02 00:00:00 to 2023-12-29 00:00:00

# %%
data
# Out:
#                  AMD      ADBE       ACN      ABBV       AOS       AES  \
# Date
# 2013-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2013-01-03 -0.251265 -0.136298 -0.320318 -0.224512 -0.126175 -0.329718
# 2013-01-04 -0.903109 -0.735358 -0.669920 -0.148952 -0.778380 -0.925163
# 2013-01-07 -0.854302 -0.307664 -0.297903 -0.525307 -0.195228 -0.043745
# 2013-01-08 -0.470716 -0.617137 -0.682213 -0.066161 -0.899132 -0.466016
# ...              ...       ...       ...       ...       ...       ...
# 2023-12-22 -0.448301 -0.381779 -0.909617 -0.865148 -0.537238 -0.798988
# 2023-12-26 -0.827910 -0.431309 -0.350687 -0.393709 -0.515184 -0.807303
# 2023-12-27 -0.742589 -0.345264 -0.497108 -0.514100 -0.598337 -0.366956
# 2023-12-28 -0.739335 -0.426970 -0.244035 -0.430947 -0.499277 -0.576283
# 2023-12-29 -0.337672 -0.514100 -0.382863 -0.506869 -0.549168 -0.339841
#
#                  MMM       ABT
# Date
# 2013-01-02       NaN       NaN
# 2013-01-03 -0.415040 -0.991323
# ...
